# %% [markdown]
# <a href="https://colab.research.google.com/github/Edvandro-Nogueira/TCC-Univesp/blob/main/Tratamento_de_Dados_TCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# URL:
# https://github.com/jghm-f/FACTCK.BR/blob/master/FACTCKBR.tsv

# %%
import pandas as pd

# %%
data = pd.read_table('https://raw.githubusercontent.com/jghm-f/FACTCK.BR/master/FACTCKBR.tsv')
data
# Out:
#                                                     URL  \
# 0     https://aosfatos.org/noticias/governo-bolsonar...
# 1     https://aosfatos.org/noticias/nao-e-miriam-lei...
# 2     https://aosfatos.org/noticias/nao-e-verdade-qu...
# 3     https://aosfatos.org/noticias/nao-e-de-mulher-...
# 4     https://aosfatos.org/noticias/e-falso-que-refo...
# ...                                                 ...
# 1308  https://piaui.folha.uol.com.br/lupa/2018/05/17...
# 1309  https://piaui.folha.uol.com.br/lupa/2018/05/16...
# 1310  https://piaui.folha.uol.com.br/lupa/2018/05/16...
# 1311  https://piaui.folha.uol.com.br/lupa/2018/05/15...
# 1312  https://piaui.folha.uol.com.br/lupa/2018/05/15...
#
#                                 Author        datePublished  \
# 0               https:www.aosfatos.org           2019-07-22
# 1               https:www.aosfatos.org           2019-07-22
# 2               https:www.aosfatos.org           2019-07-22
# 3               https:www.aosfatos.org           2019-07-18
# 4               https:www.aosfatos.org           2019-07-17
# ...                                ...                  ...
# 1308  https:piaui.folha.uol.com.brlupa  2018-05-17 15:23:40
# 1309  https:piaui.folha.uol.com.brlupa  2018-05-16 17:14:19
# 1310  https:piaui.folha.uol.com.brlupa  2018-05-16 12:00:30
# 1311  https:piaui.folha.uol.com.brlupa  2018-05-15 13:00:20
# 1312  https:piaui.folha.uol.com.brlupa  2018-05-15 13:00:20
#
#                                           claimReviewed  \
# 0     Espaço dedicado para os eleitores do Bolsonaro...
# 1     Vos apresento a funcionária protegida pela Glo...
# 2     Você sabia que Benedita da Silva já foi embaix...
# 3     QUEM  A MULHER QUE EMPURROU O PADRE MARCELO ROSSI
# 4     As crueldades da Reforma da PrevidênciaPessoas...
# ...                                                 ...
# 1308  Cármen Lúcia e Raquel Dogde acabam de pedir pr...
# 1309  Marina assina carta em prol do casamento homos...
# 1310  Tribunal divulga documento que prova inocência...
# 1311  Direção do Hospital das Clínicas de São Paulo ...
# 1312  Médico quebra o silêncio: A vacina contra a gr...
#
#                                              reviewBody  \
# 0     Publicações que circulam nas redes sociais vej...
# 1     Uma foto de um treinamento de defesa contra as...
# 2      falsa a informação de que a deputada federal ...
# 3     Modificada digitalmente para incluir o filtro ...
# 4     Uma publicação que circula nas redes sociais a...
# ...                                                 ...
# 1308                                              Empty
# 1309                                              Empty
# 1310                                              Empty
# 1311                                              Empty
# 1312                                              Empty
#
#                                                   title  ratingValue  \
# 0     Governo Bolsonaro não suspendeu distribuição d...          1.0
# 1     Não é Miriam Leitão quem segura fuzil ao lado ...          1.0
# 2     Não é verdade que Benedita da Silva foi embaix...          1.0
# 3     Não é de mulher que empurrou padre Marcelo Ros...          1.0
# 4     É falso que reforma tira de pessoas com defici...          1.0
# ...                                                 ...          ...
# 1308  #Verificamos: PGR e Cármen Lúcia não pediram p...          4.0
# 1309  #Verificamos: Marina não assinou carta 'em pro...          4.0
# 1310  #Verificamos: decisão de tribunal do DF não 'p...          4.0
# 1311  #Verificamos: vacina contra gripe não causa 's...          4.0
# 1312  #Verificamos: vacina contra gripe não causa 's...          4.0
#
#       bestRating alternativeName
# 0              5           falso
# 1              5           falso
# 2              5           falso
# 3              5           falso
# 4              5           falso
# ...          ...             ...
# 1308           6           Falso
# 1309           6           Falso
# 1310           6           Falso
# 1311           6           Falso
# 1312           6           Falso
#
# [1313 rows x 9 columns]

# %%
data['alternativeName'].unique()
# Out:
# array(['falso', 'distorcido', 'impreciso', 'exagerado', 'insustentável',
#        'verdadeiro', 'outros', 'Falso', 'Subestimado', 'Verdadeiro',
#        'Exagerado', 'Impossível provar', 'Discutível', 'Sem contexto',
#        nan, 'Distorcido', 'De olho', 'Verdadeiro, mas',
#        'Ainda é cedo para dizer'], dtype=object)

# %%
data = data.drop(['URL', 'Author', 'datePublished', 'claimReviewed', 'reviewBody', 'ratingValue', 'bestRating'], axis=1)
data = data.reindex(columns=['alternativeName', 'title'])
data.columns = ['label', 'preprocessed_news']
data
# Out:
#       label                                  preprocessed_news
# 0     falso  Governo Bolsonaro não suspendeu distribuição d...
# 1     falso  Não é Miriam Leitão quem segura fuzil ao lado ...
# 2     falso  Não é verdade que Benedita da Silva foi embaix...
# 3     falso  Não é de mulher que empurrou padre Marcelo Ros...
# 4     falso  É falso que reforma tira de pessoas com defici...
# ...     ...                                                ...
# 1308  Falso  #Verificamos: PGR e Cármen Lúcia não pediram p...
# 1309  Falso  #Verificamos: Marina não assinou carta 'em pro...
# 1310  Falso  #Verificamos: decisão de tribunal do DF não 'p...
# 1311  Falso  #Verificamos: vacina contra gripe não causa 's...
# 1312  Falso  #Verificamos: vacina contra gripe não causa 's...
#
# [1313 rows x 2 columns]

# %%
contagem = data['label'].value_counts()
contagem
# Out:
# Falso                      615
# falso                      328
# Verdadeiro                 119
# Exagerado                   87
# Sem contexto                42
# distorcido                  29
# Distorcido                  25
# Impossível provar           20
# Discutível                  12
# Subestimado                  6
# Ainda é cedo para dizer      6
# insustentável                5
# exagerado                    4
# Verdadeiro, mas              4
# De olho                      3
# impreciso                    2
# verdadeiro                   1
# outros                       1
# Name: label, dtype: int64

# %%
data = data[(data['label'] == 'verdadeiro') | (data['label'] == 'Verdadeiro') | (data['label'] == 'falso') | (data['label'] == 'Falso')]
data
# Out:
#       label                                  preprocessed_news
# 0     falso  Governo Bolsonaro não suspendeu distribuição d...
# 1     falso  Não é Miriam Leitão quem segura fuzil ao lado ...
# 2     falso  Não é verdade que Benedita da Silva foi embaix...
# 3     falso  Não é de mulher que empurrou padre Marcelo Ros...
# 4     falso  É falso que reforma tira de pessoas com defici...
# ...     ...                                                ...
# 1308  Falso  #Verificamos: PGR e Cármen Lúcia não pediram p...
# 1309  Falso  #Verificamos: Marina não assinou carta 'em pro...
# 1310  Falso  #Verificamos: decisão de tribunal do DF não 'p...
# 1311  Falso  #Verificamos: vacina contra gripe não causa 's...
# 1312  Falso  #Verificamos: vacina contra gripe não causa 's...
#
# [1063 rows x 2 columns]

# %%
contagem = data['label'].value_counts()
contagem
# Out:
# Falso         615
# falso         328
# Verdadeiro    119
# verdadeiro      1
# Name: label, dtype: int64

# %%
data['label'] = data['label'].map({'verdadeiro': 1, 'Verdadeiro': 1, 'Falso': 0, 'falso': 0})
data
# Out:
# <ipython-input-31-a1a7181b781f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'] = data['label'].map({'verdadeiro': 1, 'Verdadeiro': 1, 'Falso': 0, 'falso': 0})
#       label                                  preprocessed_news
# 0         0  Governo Bolsonaro não suspendeu distribuição d...
# 1         0  Não é Miriam Leitão quem segura fuzil ao lado ...
# 2         0  Não é verdade que Benedita da Silva foi embaix...
# 3         0  Não é de mulher que empurrou padre Marcelo Ros...
# 4         0  É falso que reforma tira de pessoas com defici...
# ...     ...                                                ...
# 1308      0  #Verificamos: PGR e Cármen Lúcia não pediram p...
# 1309      0  #Verificamos: Marina não assinou carta 'em pro...
# 1310      0  #Verificamos: decisão de tribunal do DF não 'p...
# 1311      0  #Verificamos: vacina contra gripe não causa 's...
# 1312      0  #Verificamos: vacina contra gripe não causa 's...
#
# [1063 rows x 2 columns]

# %%
contagem = data['label'].value_counts()
contagem
# Out:
# 0    943
# 1    120
# Name: label, dtype: int64
